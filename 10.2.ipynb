# %% [markdown]
# <a href="https://colab.research.google.com/github/Parkjaeseong1210/re-python/blob/main/10.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4, 5, 6])
arr2 = arr1.reshape(3,2)

print(arr1)
print(arr2)
# Out:
# [1 2 3 4 5 6]
# [[1 2]
#  [3 4]
#  [5 6]]
