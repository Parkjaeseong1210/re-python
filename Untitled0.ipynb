# %% [markdown]
# <a href="https://colab.research.google.com/github/Parkjaeseong1210/re-python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print(arr[1])
print(arr[1:4])
# Out:
# 2
# [2 3 4]
